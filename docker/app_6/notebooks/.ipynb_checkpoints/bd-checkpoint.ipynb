# %%
from sqlalchemy import create_engine
import pandas as pd 
engine = create_engine("postgresql://user:password@app_4:55432/mydb")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 from sqlalchemy import create_engine
# ----> 3 engine = create_engine("postgresql://postgres:password@db:5432/mydb")
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/create.py:601, in create_engine(url, **kwargs)
#     599         if k in kwargs:
#     600             dbapi_args[k] = pop_kwarg(k)
# ...

# %%
# !pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 30.4 kB/s eta 0:00:0000:0100:04m
# ...
